# %% [markdown]
# # Projeto 1 - Ciência dos Dados

# %% [markdown]
# Nome: Alison Araujo
#
# Nome: Gabrielly Carneiro

# %% [markdown]
# Atenção: Serão permitidos grupos de três pessoas, mas com uma rubrica mais exigente. Grupos deste tamanho precisarão fazer um questionário de avaliação de trabalho em equipe

# %% [markdown]
# ___
# Carregando algumas bibliotecas:

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import re
from unidecode import unidecode
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('word_tokenize')
stopwordsdic = stopwords.words('portuguese')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\aliso\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aliso\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Error loading word_tokenize: Package 'word_tokenize' not
# [nltk_data]     found in index

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# c:\Users\aliso\OneDrive - Insper - Institudo de Ensino e Pesquisa\Insper\2023.2\Ciência de Dados\C.DadosP1

# %% [markdown]
# Carregando a base de dados com os tweets classificados manualmente:

# %%
train = pd.read_excel('dados_treino.xlsx')
train.head(5)
# Out:
#                                             Mensagem  \
# 0  Para quem gosta de poemas simples, esse é o li...
# 1  Quando vi o lançamento pensei que finalmente p...
# 2  É incrível como esses escritores e "intelectua...
# 3  Se desse pra devolver eu devolvia, nao é por e...
# 4  Futilidade, inutilidade, desperdício de papel,...
#
#   Acionável (para amazon)/direcionável (para editora)/não acionável(para o autor ou irrelevante)
# 0                                                  N
# 1                                                  D
# 2                                                  N
# 3                                                  N
# 4                                                  N

# %%
test = pd.read_excel('dados_teste.xlsx')
test.head(5)
# Out:
#                                             Mensagem  \
# 0  O livro é prolixo, redundante, doentio. Sou su...
# 1  Bom livro e história envolvente. Porém, o leit...
# 2  Fala tudo que todos já sabem, sem falar que nã...
# 3  Ganhei na compra do Kindle. Não é estilo de li...
# 4  Custa crer que um livro tão medíocre, embora m...
#
#   Acionável (para amazon)/direcionável (para editora)/não acionável(autor ou irrelevante)
# 0                                                  N
# 1                                                  D
# 2                                                  N
# 3                                                  N
# 4                                                  N

# %% [markdown]
# ___
# ## Classificador automático

# %% [markdown]
# Na primeira etapa, de classificação manual, consideramos três targets para os reviews: Acionável, Direcionável e Não Acionável.
#
# - Acionável: para ser considerado "acionável" ("A") o review deve ser passível de alguma ação pela Amazon, ou seja, o review deve ser sobre entrega, estado do produto, contato com o suporte, etc.
# - Direcionável: para o target "direcionável" ("D") foram considerados comentários relativos à editora, como qualidade do material do livro, preço do livro e do e-book, tradução e edição.
# - Não Acionáveis: por fim, os não acionáveis ("NA") eram comentários relativos ao autor, ao apreço pelo conteúdo do livro, ou comentários irrelavantes.

# %% [markdown]
# ___
# ### Montando um Classificador Naive-Bayes
#
# Considerando apenas as mensagens da planilha Treinamento, ensine  seu classificador.

# %%
#Criar uma função que transforma as frases da planilha em um texto só
def transforma_em_string(coluna):
    texto = ''
    for linha in coluna:
        texto += linha + ' '
    return texto

# %%
#Criar uma função que limpa todas as pontuações
def cleanup(text):
    punctuation = r'[´"!-.:?;$,/~^_=+*&¨%$#@|\{}()[\]]'
    pattern = re.compile(punctuation)
    text_subbed = re.sub(pattern, '', text)
    return text_subbed

# %%
#Cria uma função que limpa os espaços duplicados
def limpa_espaco(text):
    punctuation = r'[\n]'  # Adicione os caracteres desejados aqui
    pattern = re.compile(punctuation)
    text_subbed = re.sub(pattern, '', text)
    return text_subbed

# %%
#Criando uma função para remover emoji
def remove_emoji(text):
    text_without_emojis = unidecode(text)
    return text_without_emojis

# %%
#Criando a função de stopwords
def stopwords(texto):
    palavras = word_tokenize(texto, language='portuguese') # Tokenize é analisar palavras individualmente, basicamente
    palavras_sem_stopword = []
    for palavra in palavras:
        if palavra not in stopwordsdic:
            palavras_sem_stopword.append(palavra)
    # Reúna as palavras sem stopwords em uma string novamente
    texto_sem_stopword = ' '.join(palavras_sem_stopword)
    return texto_sem_stopword

# %%
# Criar uma função que realize todas as funções de limpeza
def limpa_tudo(mensagem):
    #Aplicando a função de limpeza de pontuação
    texto = cleanup(mensagem)
    #Deixando tudo em letra minúscula
    texto = texto.lower()
    #Removendo emoji
    texto = remove_emoji(texto)
    #Aplicando a função de limpeza de espaço
    texto = limpa_espaco(texto)
    #Removendo stopwords
    texto = stopwords(texto)
    return texto

# %%
    #separando cada palavra
    #texto = texto.split()
    #set para tirar repetição


train.head()
train['Mensagem limpa'] = [limpa_tudo(x) for x in list(train['Mensagem'])]
L = []
for x in list(train['Mensagem']):
    L.append(limpa_tudo(x))
    
train.head()
# Out:
#   Cell In[12], line 10
#     L.append(limpa_tudo(x))
#     ^
# IndentationError: expected an indented block after 'for' statement on line 9

# %%
## Aplicando as limpezas na base treino
treino = limpa_tudo(train.Mensagem)   #retorna uma lista de todas as palavras
treino
# Out:
# ['gosta',
#  'poemas',
#  'simples',
#  'livro',
#  'ideal',
#  'autora',
#  'faz',
#  'refletir',
#  'sobre',
#  'alguns',
#  'elementos',
#  'comuns',
#  'vida',
#  'mulheres',
#  'jeito',
#  'bem',
#  'leve',
#  'vi',
#  'lancamento',
#  'pensei',
#  'finalmente',
#  'poderia',
#  'livrar',
#  'ebook',
#  'distribuidos',
#  'net',
#  'graca',
#  'vi',
#  'preco',
#  'mudei',
#  'ideia',
#  'espero',
#  'ninguem',
#  'compre',
#  'queremos',
#  'livros',
#  'digitais',
#  'democraticos',
#  'precos',
#  'acessiveis',
#  'nao',
#  'trampolim',
#  'riqueza',
#  'livro',
#  'digital',
#  'nao',
#  'utiliza',
#  'tinta',
#  'papel',
#  'nao',
#  'precisa',
#  'distribuicao',
#  'fisica',
#  'dispensa',
#  'muita',
#  'mao',
#  'obra',
#  'tudo',
#  'deveria',
#  'contribuir',
#  'valor',
#  'acessivel',
#  'incrivel',
#  'escritores',
#  'intelectuais',
#  'colocam',
#  'cristianismo',
#  'responsabilidade',
#  'todos',
#  'males',
#  'universo',
#  'simplesmente',
#  'ignoram',
#  'avanco',
#  'isla',
#  'radical',
#  'quer',
#  'botar',
#  'hejab',
#  'burca',
#  'cabeca',
#  'cada',
#  'mulher',
#  'mundo',
#  'deseja',
#  'subjugar',
#  'mulher',
#  'extremo',
#  'ponto',
#  'paises',
#  'arabes',
#  'mulher',
#  'condenada',
#  'morte',
#  'ter',
#  'sido',
#  'estuprada',
#  'ainda',
#  'querem',
#  'impor',
#  'lei',
#  'onde',
#  'quer',
#  'cheguem',
#  'culpa',
#  'tudo',
#  'sao',
#  'cristaos',
#  'enfim',
#  'livro',
#  'profundo',
#  'mal',
#  'gosto',
#  'preconceituoso',
#  'irresponsavel',
#  'so',
#  'faz',
#  'piorar',
#  'embotar',
#  'ainda',
#  'cabecas',
#  'fracas',
#  'pessoas',
#  'influenciaveis',
#  'autora',
#  'afirma',
#  'distopia',
#  'afirma',
#  'grandes',
#  'chances',
#  'acontecer',
#  'parametro',
#  'verificavel',
#  'escritora',
#  'usou',
#  'atestar',
#  'disse',
#  'so',
#  'tirou',
#  'daquele',
#  'lugar',
#  'lixo',
#  'ideologico',
#  'universidades',
#  'brasileiras',
#  'ja',
#  'estao',
#  'cheias',
#  'nao',
#  'precisamos',
#  'entulho',
#  'traduzido',
#  'portugues',
#  'desse',
#  'pra',
#  'devolver',
#  'devolvia',
#  'nao',
#  'nao',
#  'pensar',
#  'igual',
#  'autor',
#  'achei',
#  'coletanea',
#  'cansativa',
#  'repetitiva',
#  'vai',
#  'tijolo',
#  'abandonado',
#  'aqui',
#  'casa',
#  'futilidade',
#  'inutilidade',
#  'desperdicio',
#  'papel',
#  'tempo',
#  'dinheiro',
#  'graca',
#  'queremos',
#  'livro',
#  'vai',
#  'perder',
#  'tempo',
#  'autor',
#  'tenta',
#  'mostrar',
#  'outro',
#  'lado',
#  'livro',
#  'buscando',
#  'referencias',
#  'bibliograficas',
#  'contrariem',
#  'tradicionais',
#  'referencias',
#  'autor',
#  'usa',
#  'sao',
#  'unicas',
#  'quer',
#  'usar',
#  'prova',
#  'livro',
#  'radical',
#  'quer',
#  'acusar',
#  'negros',
#  'serem',
#  'culpados',
#  'propria',
#  'escravidao',
#  'desmerecer',
#  'invencoes',
#  'artistas',
#  'brasileiros',
#  'qualificando',
#  'ingleses',
#  'americanos',
#  'nivel',
#  'reis',
#  'herois',
#  'alem',
#  'autor',
#  'citar',
#  'alguns',
#  'radicais',
#  'politicos',
#  'direita',
#  'referencia',
#  'finalizar',
#  'livro',
#  'autor',
#  'poderia',
#  'ter',
#  'falado',
#  'alguma',
#  'qualidade',
#  'nacional',
#  'resolveu',
#  'alfinetar',
#  'comunistas',
#  'perda',
#  'tempo',
#  'comecou',
#  'boa',
#  'istoria',
#  'meio',
#  'pouco',
#  'enrolado',
#  'embromou',
#  'romance',
#  'dando',
#  'saber',
#  'violao',
#  'irmao',
#  'novo',
#  'diferente',
#  'mundo',
#  'novo',
#  'so',
#  'deve',
#  'expandindo',
#  'espero',
#  'proximo',
#  'melhor',
#  'bem',
#  'sei',
#  'onde',
#  'comecar',
#  'historia',
#  'representacao',
#  'machismo',
#  'repugnante',
#  'possa',
#  'imaginar',
#  'arthur',
#  'escroto',
#  'jamais',
#  'nunca',
#  'arma',
#  'apontada',
#  'pra',
#  'cabeca',
#  'ficaria',
#  'homem',
#  'nojento',
#  'desses',
#  'fiquei',
#  'chocada',
#  'forma',
#  'degradante',
#  'figura',
#  'feminina',
#  'retratada',
#  'sempre',
#  'interesseira',
#  'futil',
#  'nao',
#  'pura',
#  'virgem',
#  'pudica',
#  'protagonista',
#  'autora',
#  'tambem',
#  'presta',
#  'gama',
#  'desservicos',
#  'sendo',
#  'extremamente',
#  'preconceituosa',
#  'pilula',
#  'dia',
#  'seguinte',
#  'nao',
#  'aborto',
#  'estudante',
#  'universitaria',
#  'jamais',
#  'pensamento',
#  'tao',
#  'estupido',
#  'forma',
#  'totalmente',
#  'desrespeitosa',
#  'tratou',
#  'tema',
#  'estrupo',
#  'pessoa',
#  'gostar',
#  'bdsm',
#  'nao',
#  'diz',
#  'nada',
#  'sobre',
#  'carater',
#  'matheus',
#  'nao',
#  'deixa',
#  'boa',
#  'pessoa',
#  'pq',
#  'gosta',
#  'chicotinho',
#  'sete',
#  'pontas',
#  'desde',
#  'concentimento',
#  'coisa',
#  'sr',
#  'redencao',
#  'nunca',
#  'solicitou',
#  'maiana',
#  'ha',
#  'outras',
#  'questoes',
#  'achei',
#  'igualmente',
#  'repugnantes',
#  'sao',
#  'quase',
#  'fizeram',
#  'vomitar',
#  'menos',
#  'menos',
#  'nao',
#  'dicas',
#  'obra',
#  'sao',
#  'lugarcomum',
#  'nao',
#  'trazem',
#  'novidade',
#  'alguma',
#  'sao',
#  'pouco',
#  'producentes',
#  'box',
#  'veio',
#  'todo',
#  'detonado',
#  'fiquei',
#  'triste',
#  'porque',
#  'nunca',
#  'problemas',
#  'amazon',
#  'pena',
#  'demorei',
#  'tanto',
#  'pra',
#  'decidir',
#  'comprar',
#  'box',
#  'compro',
#  'vem',
#  'assim',
#  'ebook',
#  'possui',
#  'erro',
#  'formatacao',
#  'capitulos',
#  'capitulos',
#  'theon',
#  'daenerys',
#  'posicao',
#  '4158',
#  'nao',
#  'possui',
#  'identificacao',
#  'novo',
#  'capitulo',
#  'conteudo',
#  'texto',
#  'pode',
#  'levar',
#  'ma',
#  'interpretacao',
#  'conteudo',
#  'ja',
#  'coincidencia',
#  'texto',
#  'faz',
#  'mencao',
#  'local',
#  'personagem',
#  'espero',
#  'erro',
#  'corrigido',
#  'formatacao',
#  'kindle',
#  'ridicula',
#  'problema',
#  'antigo',
#  'nao',
#  'resolvido',
#  'ate',
#  'amazon',
#  'clientes',
#  'esperam',
#  'produto',
#  'melhor',
#  'comprei',
#  'dois',
#  'livros',
#  'dois',
#  'vieram',
#  'super',
#  'amassados',
#  'parte',
#  'baixo',
#  'outro',
#  'parte',
#  'cima',
#  'nao',
#  'so',
#  'capa',
#  'folhas',
#  'tambem',
#  'nao',
#  'curti',
#  'livro',
#  'gosto',
#  'livros',
#  'eroticos',
#  'nao',
#  'agradou',
#  'achei',
#  'legal',
#  'fato',
#  'livro',
#  'passar',
#  'brasil',
#  'pois',
#  'autora',
#  'fala',
#  'lugares',
#  'atividades',
#  'conheco',
#  'relacao',
#  'parte',
#  'erotica',
#  'achei',
#  'forcada',
#  'ate',
#  'agressiva',
#  'metade',
#  'pro',
#  'final',
#  'livro',
#  'ficou',
#  'bem',
#  'melhor',
#  'menos',
#  'forcado',
#  'nao',
#  'recomendo',
#  'nao',
#  'leria',
#  'novamente',
#  'oportunidade',
#  'comprei',
#  'achando',
#  'vantagem',
#  'preco',
#  'atrativo',
#  'filha',
#  'abriu',
#  'livros',
#  'primeira',
#  'vez',
#  'folhas',
#  'soltaram',
#  'livro',
#  'colecao',
#  'harry',
#  'potter',
#  'comprei',
#  '8',
#  'anos',
#  'perfeito',
#  'estado',
#  'conservacao',
#  'nao',
#  'entendi',
#  'baixissima',
#  'qualidade',
#  'desse',
#  'produto',
#  'pessoal',
#  'achei',
#  'pessimo',
#  'livro',
#  'terminei',
#  'ler',
#  'quase',
#  'vomitando',
#  'esforco',
#  'pra',
#  'concluir',
#  'tao',
#  'ruim',
#  'leitura',
#  'pessima',
#  'historia',
#  'chata',
#  'nao',
#  'recomendo',
#  'ninguem',
#  'saiam',
#  'dessa',
#  'primeira',
#  'distopia',
#  'li',
#  'pe',
#  'atras',
#  'ler',
#  'outras',
#  'duas',
#  'ja',
#  'havia',
#  'comprado',
#  'kindle',
#  'bom',
#  'boa',
#  'sorte',
#  'aventureiros',
#  'livro',
#  'maravilhoso',
#  'otimo',
#  'escorar',
#  'porta',
#  'nao',
#  'consegui',
#  'terminar',
#  'leitura',
#  'achei',
#  'superficial',
#  'infantil',
#  'abordagem',
#  'sobre',
#  'toc',
#  'conseguiu',
#  'prender',
#  'atencao',
#  'nao',
#  'recomendo',
#  'nao',
#  'terminei',
#  'ler',
#  'historia',
#  'nao',
#  'agradando',
#  'linguagem',
#  'criada',
#  'livro',
#  'confunde',
#  'final',
#  'livro',
#  'glossario',
#  'palavras',
#  'trabalhoso',
#  'ver',
#  'significado',
#  'cada',
#  'palavra',
#  'sao',
#  'muitas',
#  'algumas',
#  'conseguia',
#  'entender',
#  'maioria',
#  'acabou',
#  'perdendo',
#  'tornou',
#  'leitura',
#  'cansativa',
#  'ainda',
#  'nao',
#  'voltaria',
#  'reler',
#  'pena',
#  'pois',
#  'laranja',
#  'mecanica',
#  'considerada',
#  'pais',
#  'distopia',
#  'genero',
#  'adoro',
#  'atender',
#  'expectativa',
#  'so',
#  'decepcao',
#  'desde',
#  'dia',
#  '1105',
#  'fiz',
#  'pedido',
#  'primeira',
#  'vez',
#  'produto',
#  'extraviado',
#  'segunda',
#  'vez',
#  'peco',
#  'ate',
#  'agora',
#  'nao',
#  'veio',
#  'horrivel',
#  'nao',
#  'dei',
#  'conta',
#  'ler',
#  'tudo',
#  'nao',
#  'consigo',
#  'entender',
#  'mulher',
#  'aceita',
#  'tipo',
#  'situacao',
#  'ter',
#  'tantas',
#  'fas',
#  'conta',
#  'jatinho',
#  'carros',
#  'todos',
#  'outros',
#  'bens',
#  'materiais',
#  'obra',
#  'prima',
#  'idiotice',
#  'nacional',
#  'produto',
#  'veio',
#  'defeito',
#  'capa',
#  'descolada',
#  'algumas',
#  'paginas',
#  'estao',
#  'grudadas',
#  'vi',
#  'apenas',
#  'hoje',
#  'porque',
#  'entreguei',
#  'presente',
#  'irma',
#  'abriu',
#  'mostrou',
#  'comprei',
#  'promocao',
#  'feita',
#  'cidade',
#  'sao',
#  'paulo',
#  'porem',
#  'nao',
#  'sei',
#  'acessar',
#  'produto',
#  'nao',
#  'explicacao',
#  'alguma',
#  'pessimo',
#  'tentativa',
#  'fazer',
#  'dinheiro',
#  'apenas',
#  'traz',
#  'informacoes',
#  'mentirosas',
#  'alem',
#  'nao',
#  'conter',
#  'fontes',
#  'confiaveis',
#  'nunca',
#  'sera',
#  'livro',
#  'historia',
#  'maximo',
#  'humor',
#  'simples',
#  'assim',
#  'formatacao',
#  'tao',
#  'ruim',
#  'perdi',
#  'vontade',
#  'ler',
#  'livro',
#  'texto',
#  'fica',
#  'todo',
#  'lado',
#  'esquerdo',
#  'ocupando',
#  'apenas',
#  'metade',
#  'pagina',
#  'cada',
#  'pagina',
#  'acaba',
#  'tendo',
#  'poucas',
#  'frases',
#  'poxa',
#  'comprei',
#  'livro',
#  'janeiro',
#  'agora',
#  'nao',
#  'estao',
#  'desponibilizando',
#  'pra',
#  'mim',
#  'agora',
#  'vou',
#  'ter',
#  'comprar',
#  'novo',
#  'sacanagem',
#  'ne',
#  'gente',
#  'fatos',
#  'historicos',
#  'relatados',
#  'dao',
#  'conhecimento',
#  'epoca',
#  'desenrolar',
#  'fatos',
#  'mundiais',
#  'nao',
#  'vivi',
#  'livro',
#  'embora',
#  'romanceado',
#  'nao',
#  'deixa',
#  'leitura',
#  'enfadonha',
#  'trouxe',
#  'vasto',
#  'conhecimento',
#  'fatos',
#  'forma',
#  'relatada',
#  'conteudo',
#  'prendem',
#  'pessoa',
#  'leitura',
#  'livro',
#  'importante',
#  'deveras',
#  'interessante',
#  'livro',
#  'escrito',
#  'reacionarios',
#  'jornalistas',
#  'brasileiros',
#  'objetivo',
#  'claro',
#  'enaltecer',
#  'todos',
#  'personagens',
#  'historicos',
#  'posicionamento',
#  'direita',
#  'desmoralizar',
#  'personagens',
#  'possuem',
#  'pensamento',
#  'esquerda',
#  'livro',
#  'otimo',
#  'titulo',
#  'capa',
#  'bem',
#  'feita',
#  'leva',
#  'ler',
#  'porem',
#  'medida',
#  'prosseguindo',
#  'leitura',
#  'comecei',
#  'perceber',
#  'forte',
#  'conteudo',
#  'ideologico',
#  'desfacado',
#  'procurei',
#  'pesquisar',
#  'autor',
#  'entender',
#  'objetivo',
#  'livro',
#  'nao',
#  'baseado',
#  'fontes',
#  'confiaveis',
#  'apenas',
#  'pinca',
#  'fatos',
#  'nao',
#  'comprovados',
#  'confirmar',
#  'teses',
#  'questionaveis',
#  'nao',
#  'percam',
#  'tempo',
#  'lixo',
#  'sempre',
#  'ouvir',
#  'falar',
#  'bem',
#  'dessa',
#  'escritora',
#  'tavez',
#  'nao',
#  'captado',
#  'estilo',
#  'autora',
#  'fato',
#  'detestei',
#  'livro',
#  'so',
#  'nao',
#  'dei',
#  'nota',
#  'minima',
#  'porque',
#  'escrita',
#  'razoavel',
#  'coisas',
#  'piores',
#  'ai',
#  'adoro',
#  'boa',
#  'estoria',
#  'pra',
#  'passar',
#  'tempo',
#  'fato',
#  'leitura',
#  'bastante',
#  'cheia',
#  'cliches',
#  'entediou',
#  'bastante',
#  'alguns',
#  'podem',
#  'ate',
#  'achar',
#  'tema',
#  'depressivo',
#  'garota',
#  'trabalha',
#  'cara',
#  'tetraplegico',
#  'ambos',
#  'descobrem',
#  'novo',
#  'sentido',
#  'vida',
#  'nao',
#  'necessariamente',
#  'deveria',
#  'achou',
#  'livro',
#  'bem',
#  'depressivo',
#  'veja',
#  'adorei',
#  'culpa',
#  'estrelas',
#  'resumo',
#  'livro',
#  'pode',
#  'pra',
#  'voce',
#  'pessoa',
#  'bastante',
#  'sensivel',
#  'gosta',
#  'livros',
#  'facam',
#  'chorar',
#  'frustrado',
#  'comprei',
#  'livro',
#  'conhecer',
#  'leonardo',
#  'vinci',
#  'sr',
#  'walter',
#  'isaacson',
#  'ateve',
#  'cadernos',
#  'leonardo',
#  'deu',
#  'aula',
#  'arte',
#  'pintura',
#  'escultura',
#  'nao',
#  'objetivo',
#  'adquirir',
#  'ebook',
#  'baseado',
#  'nesta',
#  'biografia',
#  'sr',
#  'walter',
#  'saiu',
#  'lista',
#  'autores',
#  'quero',
#  'lerja',
#  'li',
#  '30',
#  'livro',
#  'vou',
#  'ate',
#  'fim',
#  'aborrecido',
#  'bobagem',
#  '70',
#  'livro',
#  'sao',
#  'descricoes',
#  'trepadas',
#  'estoria',
#  'si',
#  'igual',
#  'milhares',
#  'personagem',
#  'feminina',
#  'ainda',
#  'existe',
#  'masculina',
#  'sonho',
#  'adolescente',
#  'nunca',
#  'problemas',
#  'amazon',
#  'agora',
#  'tempo',
#  'efetuar',
#  'compra',
#  'percebi',
#  'livro',
#  ...]

# %%
# Cria uma função que guarda as palavras em pd.Series
def cria_pdseries(lista):
    tabela = pd.Series(lista)
    return tabela

#Cria uma função que retorna a frequência absoluta de cada palavra no texto
def freq_abs(tabela):
    absoluta = tabela.value_counts()
    return absoluta

#Cria uma função que retorna a frequência relativa de cada palavra no texto
def freq_rel(tabela):
    relativa = tabela.value_counts(True)
    return relativa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\aliso\OneDrive - Insper - Institudo de Ensino e Pesquisa\Insper\2023.2\Ciência de Dados\C.DadosP1\Projeto1 Template Gabi's Version.ipynb Cell 23 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/aliso/OneDrive%20-%20Insper%20-%20Institudo%20de%20Ensino%20e%20Pesquisa/Insper/2023.2/Ci%C3%AAncia%20de%20Dados/C.DadosP1/Projeto1%20Template%20Gabi%27s%20Version.ipynb#Y114sZmlsZQ%3D%3D?line=12'>13</a>     relativa = tabela.value_counts(True)
#      <a href='vscode-notebook-cell:/c%3A/Users/aliso/OneDrive%20-%20Insper%20-%20Institudo%20de%20Ensino%20e%20Pesquisa/Insper/2023.2/Ci%C3%AAncia%20de%20Dados/C.DadosP1/Projeto1%20Template%20Gabi%27s%20Version.ipynb#Y114sZmlsZQ%3D%3D?line=13'>14</a>     return relativa
# ---> <a href='vscode-notebook-cell:/c%3A/Users/aliso/OneDrive%20-%20Insper%20-%20Institudo%20de%20Ensino%20e%20Pesquisa/Insper/2023.2/Ci%C3%AAncia%20de%20Dados/C.DadosP1/Projeto1%20Template%20Gabi%27s%20Version.ipynb#Y114sZmlsZQ%3D%3D?line=15'>16</a> tabela
#
# NameError: name 'tabela' is not defined

# %% [markdown]
# ___
# ### Verificando a performance do Classificador
#
# Agora você deve testar o seu classificador com a base de Testes.

# %% [markdown]
# ___
# ### Concluindo

# %%
#a probabilidade de todas as palavras estarem contidas num texto não é a mesma?

# %% [markdown]
# ___
# ### Qualidade do Classificador a partir de novas separações dos tweets entre Treinamento e Teste
#
# Caso for fazer esse item do Projeto

# %% [markdown]
# ___
# ## Aperfeiçoamento:
#
# Trabalhos que conseguirem pelo menos conceito B vão evoluir em conceito dependendo da quantidade de itens avançados:
#
# * IMPLEMENTOU outras limpezas e transformações que não afetem a qualidade da informação contida nos tweets. Ex: stemming, lemmatization, stopwords
# * CONSIDEROU mais de duas categorias na variável Target e INCREMENTOU a quantidade de notícias, mantendo pelo menos 250 notícias por categoria (OBRIGATÓRIO PARA TRIOS, sem contar como item avançado)
# * Para Target com duas categorias: CRIOU pelo menos quatro categorias intermediárias de relevância baseadas na probabilidade: ex.: muito relevante, relevante, neutro, irrelevante, muito irrelevante
# * EXPLICOU porquê não pode usar o próprio classificador para gerar mais amostras de treinamento
# * PROPÔS diferentes cenários para Naïve Bayes fora do contexto do projeto (pelo menos dois cenários, exceto aqueles já apresentados em sala pelos professores: por exemplo, filtro de spam)
# * SUGERIU e EXPLICOU melhorias reais com indicações concretas de como implementar (indicar como fazer e indicar material de pesquisa)
# * FEZ o item Qualidade do Classificador a partir de novas separações das Notícias entre Treinamento e Teste descrito no enunciado do projeto (OBRIGATÓRIO para conceitos A ou A+)

# %% [markdown]
# ___
# ## Referências

# %% [markdown]
# [Naive Bayes and Text Classification](https://arxiv.org/pdf/1410.5329.pdf)  **Mais completo**
#
# [A practical explanation of a Naive Bayes Classifier](https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/) **Mais simples**
